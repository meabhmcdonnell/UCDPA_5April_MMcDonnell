# %% [markdown]
# # Real World Scenario

# %%
#Periodically in Ireland a General Election takes place to elect representatives from Ireland's constituencies to serve in Ireland's government.

# %%
#importing relevant libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import requests
from matplotlib import pyplot as plt

# %% [markdown]
# # 2. Importing data - Importing CSV file into a pandas DataFrame

# %%
data2016 = pd.read_csv("2016candidatedetails.csv")

# %%
data2020 = pd.read_csv("candidates2020.csv")

# %% [markdown]
# # 3. Analysing the data

# %%
data2020.head()
# Out:
#       Constituency   Surname Firstname Gender          Party  \
# 0  Carlow-Kilkenny   AYLWARD     BOBBY      M    Fianna Fáil
# 1  Carlow-Kilkenny     BYRNE    HELENA      F  Renua Ireland
# 2  Carlow-Kilkenny   DEERING       PAT      M      Fine Gael
# 3  Carlow-Kilkenny  FUNCHION  KATHLEEN      F      Sinn Féin
# 4  Carlow-Kilkenny     HAYES      ALAN      M      Non-Party
#
#   Party Abbreviation  Count Number  Required To Reach Quota  \
# 0               F.F.            10                     2289
# 1               R.I.            10                        0
# 2               F.G.            10                        0
# 3               S.F.            10                        0
# 4             NON-P.            10                        0
#
#    Required To Save Deposit  Votes    Result  Candidate Id  \
# 0                         0   7550       NaN           161
# 1                      1905    992  Excluded           162
# ...

# %%
data2016.head()
# Out:
#       Constituency   Surname       First Name Gender        Party  \
# 0      Galway West    Ó Cuív            Éamon      M  Fianna Fáil
# 1            Louth     Adams            Gerry      M    Sinn Féin
# 2       Cork  East     Ahern          Barbara      F  Fianna Fáil
# 3        Waterford     Ahmed  Sheik Mohiuddin      M    Non-Party
# 4  Dublin Mid-West  Akpoveta          Patrick      M    Non-Party
#
#   Party Abbreviation  Count Number  Required To Reach Quota  \
# 0               F.F.            14                        0
# 1               S.F.            11                        0
# 2               F.F.            10                     3781
# 3             NON-P.             9                        0
# 4             NON-P.            12                        0
#
#    Required To Save Deposit  Votes    Result  Candidate Id  \
# 0                         0   9539   Elected           165
# 1                         0  10661   Elected           160
# ...

# %%
data2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 551 entries, 0 to 550
# Data columns (total 16 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Constituency              551 non-null    object
#  1   Surname                   551 non-null    object
#  2   First Name                551 non-null    object
#  3   Gender                    551 non-null    object
#  4   Party                     551 non-null    object
#  5   Party Abbreviation        551 non-null    object
#  6   Count Number              551 non-null    int64
#  7   Required To Reach Quota   551 non-null    int64
#  8   Required To Save Deposit  551 non-null    int64
#  9   Votes                     551 non-null    int64
#  10  Result                    527 non-null    object
#  11  Candidate Id              551 non-null    int64
#  12  Constituency Number       551 non-null    int64
#  13  Constituency Ainm         551 non-null    object
# ...

# %%
data2020 = data2020.rename(columns={"Firstname": "First Name"})
data2020.head()
# Out:
#       Constituency   Surname First Name Gender          Party  \
# 0  Carlow-Kilkenny   AYLWARD      BOBBY      M    Fianna Fáil
# 1  Carlow-Kilkenny     BYRNE     HELENA      F  Renua Ireland
# 2  Carlow-Kilkenny   DEERING        PAT      M      Fine Gael
# 3  Carlow-Kilkenny  FUNCHION   KATHLEEN      F      Sinn Féin
# 4  Carlow-Kilkenny     HAYES       ALAN      M      Non-Party
#
#   Party Abbreviation  Count Number  Required To Reach Quota  \
# 0               F.F.            10                     2289
# 1               R.I.            10                        0
# 2               F.G.            10                        0
# 3               S.F.            10                        0
# 4             NON-P.            10                        0
#
#    Required To Save Deposit  Votes    Result  Candidate Id  \
# 0                         0   7550       NaN           161
# 1                      1905    992  Excluded           162
# ...

# %%
data2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 531 entries, 0 to 530
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Constituency              531 non-null    object
#  1   Surname                   531 non-null    object
#  2   First Name                531 non-null    object
#  3   Gender                    531 non-null    object
#  4   Party                     531 non-null    object
#  5   Party Abbreviation        531 non-null    object
#  6   Count Number              531 non-null    int64
#  7   Required To Reach Quota   531 non-null    int64
#  8   Required To Save Deposit  531 non-null    int64
#  9   Votes                     531 non-null    int64
#  10  Result                    503 non-null    object
#  11  Candidate Id              531 non-null    int64
#  12  Constituency Number       531 non-null    int64
#  13  Constituency Ainm         531 non-null    object
# ...

# %%
#replace missing values or dropping duplicates

# %%
#Looking for missing data in the 2020 dataset
print(data2020.isnull().sum())
# Out:
# Constituency                  0
# Surname                       0
# First Name                    0
# Gender                        0
# Party                         0
# Party Abbreviation            0
# Count Number                  0
# Required To Reach Quota       0
# Required To Save Deposit      0
# Votes                         0
# Result                       28
# Candidate Id                  0
# Constituency Number           0
# Constituency Ainm             0
# Unnamed: 14                 531
# Year                          0
# Full Name                     0
# dtype: int64

# %%
#Looking for missing data in the 2016 dataset
print(data2016.isnull().sum())
# Out:
# Constituency                 0
# Surname                      0
# First Name                   0
# Gender                       0
# Party                        0
# Party Abbreviation           0
# Count Number                 0
# Required To Reach Quota      0
# Required To Save Deposit     0
# Votes                        0
# Result                      24
# Candidate Id                 0
# Constituency Number          0
# Constituency Ainm            0
# Year                         0
# Full Name                    0
# dtype: int64

# %%
#replace missing values in 2020 and 2016 dataset. from above we can see that there is missing data in 2020 and 2016. For now I am going to replace the missing values with Unknown.
data2020["Result"]=data2020["Result"].fillna("Unknown")
print(data2020[["Result"]])
# Out:
#        Result
# 0     Unknown
# 1    Excluded
# 2    Excluded
# 3     Elected
# 4    Excluded
# ..        ...
# 526   Elected
# 527  Excluded
# 528  Excluded
# 529  Excluded
# 530   Elected
#
# [531 rows x 1 columns]

# %%
#I can now see that Nan was replaced with Unknown. I'll now do the same for the 2016 dataset

# %%
#dropping unnamed column 
data2020.drop(columns={"Unnamed: 14"})
# Out:
#         Constituency   Surname First Name Gender  \
# 0    Carlow-Kilkenny   AYLWARD      BOBBY      M
# 1    Carlow-Kilkenny     BYRNE     HELENA      F
# 2    Carlow-Kilkenny   DEERING        PAT      M
# 3    Carlow-Kilkenny  FUNCHION   KATHLEEN      F
# 4    Carlow-Kilkenny     HAYES       ALAN      M
# ..               ...       ...        ...    ...
# 526          Wicklow  MATTHEWS     STEVEN      M
# 527          Wicklow   O BRIEN       PAUL      M
# 528          Wicklow     SNELL       JOHN      M
# 529          Wicklow   TIMMINS      BILLY      M
# 530          Wicklow  WHITMORE  JENNIEFER      F
#
#                             Party Party Abbreviation  Count Number  \
# 0                     Fianna Fáil               F.F.            10
# 1                   Renua Ireland               R.I.            10
# 2                       Fine Gael               F.G.            10
# 3                       Sinn Féin               S.F.            10
# ...

# %%
data2016["Result"]=data2016["Result"].fillna("Unknown")
print(data2016[["Result"]])
# Out:
#        Result
# 0     Elected
# 1     Elected
# 2     Unknown
# 3    Excluded
# 4    Excluded
# ..        ...
# 546  Excluded
# 547  Excluded
# 548  Excluded
# 549  Excluded
# 550   Elected
#
# [551 rows x 1 columns]

# %%
#it appears that there are no duplicates

# %%
data2020.duplicated().sum()
# Out:
# 0

# %%
data2016.duplicated().sum()
# Out:
# 0

# %%
data2020.head()
# Out:
#       Constituency   Surname First Name Gender          Party  \
# 0  Carlow-Kilkenny   AYLWARD      BOBBY      M    Fianna Fáil
# 1  Carlow-Kilkenny     BYRNE     HELENA      F  Renua Ireland
# 2  Carlow-Kilkenny   DEERING        PAT      M      Fine Gael
# 3  Carlow-Kilkenny  FUNCHION   KATHLEEN      F      Sinn Féin
# 4  Carlow-Kilkenny     HAYES       ALAN      M      Non-Party
#
#   Party Abbreviation  Count Number  Required To Reach Quota  \
# 0               F.F.            10                     2289
# 1               R.I.            10                        0
# 2               F.G.            10                        0
# 3               S.F.            10                        0
# 4             NON-P.            10                        0
#
#    Required To Save Deposit  Votes    Result  Candidate Id  \
# 0                         0   7550   Unknown           161
# 1                      1905    992  Excluded           162
# ...

# %%
data2016.head()
# Out:
#       Constituency   Surname       First Name Gender        Party  \
# 0      Galway West    Ó Cuív            Éamon      M  Fianna Fáil
# 1            Louth     Adams            Gerry      M    Sinn Féin
# 2       Cork  East     Ahern          Barbara      F  Fianna Fáil
# 3        Waterford     Ahmed  Sheik Mohiuddin      M    Non-Party
# 4  Dublin Mid-West  Akpoveta          Patrick      M    Non-Party
#
#   Party Abbreviation  Count Number  Required To Reach Quota  \
# 0               F.F.            14                        0
# 1               S.F.            11                        0
# 2               F.F.            10                     3781
# 3             NON-P.             9                        0
# 4             NON-P.            12                        0
#
#    Required To Save Deposit  Votes    Result  Candidate Id  \
# 0                         0   9539   Elected           165
# 1                         0  10661   Elected           160
# ...

# %%
#here i want to merge First Name and Surname to identify candidates easily
data2016["Full Name"] = data2016["First Name"] + data2016["Surname"]
data2016.head()
# Out:
#       Constituency   Surname       First Name Gender        Party  \
# 0      Galway West    Ó Cuív            Éamon      M  Fianna Fáil
# 1            Louth     Adams            Gerry      M    Sinn Féin
# 2       Cork  East     Ahern          Barbara      F  Fianna Fáil
# 3        Waterford     Ahmed  Sheik Mohiuddin      M    Non-Party
# 4  Dublin Mid-West  Akpoveta          Patrick      M    Non-Party
#
#   Party Abbreviation  Count Number  Required To Reach Quota  \
# 0               F.F.            14                        0
# 1               S.F.            11                        0
# 2               F.F.            10                     3781
# 3             NON-P.             9                        0
# 4             NON-P.            12                        0
#
#    Required To Save Deposit  Votes    Result  Candidate Id  \
# 0                         0   9539   Elected           165
# 1                         0  10661   Elected           160
# ...

# %%
data2016["Gender"].value_counts(sort=True)
# Out:
# M    388
# F    163
# Name: Gender, dtype: int64

# %%
data2020["Gender"].value_counts(sort=True)
# Out:
# M    370
# F    161
# Name: Gender, dtype: int64

# %%
data2016["Party"].value_counts(sort=True)
# Out:
# Non-Party                                         159
# Fine Gael                                          88
# Fianna Fáil                                        71
# Sinn Féin                                          50
# Green Party/ Comhaontas Glas                       40
# The Labour Party                                   36
# Anti-Austerity Alliance - People Before Profit     31
# Renua Ireland                                      26
# Direct Democracy Ireland                           19
# Social Democrats                                   14
# Independents 4 Change                               5
# Workers Party                                       5
# Catholic Democrats                                  3
# Fís Nua                                             2
# Communist Party of Ireland                          1
# Irish Democratic Party                              1
# Name: Party, dtype: int64

# %%
data2020["Party"].value_counts(sort=True)
# Out:
# Non-Party                            130
# Fianna Fáil                           84
# Fine Gael                             82
# Sinn Féin                             42
# Green Party/ Comhaontas Glas          39
# Solidarity - People Before Profit     37
# The Labour Party                      31
# Aontu                                 25
# Social Democrats                      20
# Renua Ireland                         11
# Irish Freedom Party                   10
# The National Party                    10
# Workers Party                          4
# Independents 4 Change                  4
# United People                          1
# Irish Democratic Party                 1
# Name: Party, dtype: int64

# %%
sns.countplot(x="Party",data=data2020)
plt.xticks(rotation=90)
plt.show()

# %%
sns.relplot(x="Votes", y="Count Number",data=data2020, col="Party",col_wrap=2)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data2016["Party"].value_counts(normalize=True)
# Out:
# Non-Party                                         0.288566
# Fine Gael                                         0.159710
# Fianna Fáil                                       0.128857
# Sinn Féin                                         0.090744
# Green Party/ Comhaontas Glas                      0.072595
# The Labour Party                                  0.065336
# Anti-Austerity Alliance - People Before Profit    0.056261
# Renua Ireland                                     0.047187
# Direct Democracy Ireland                          0.034483
# Social Democrats                                  0.025408
# Independents 4 Change                             0.009074
# Workers Party                                     0.009074
# Catholic Democrats                                0.005445
# Fís Nua                                           0.003630
# Communist Party of Ireland                        0.001815
# Irish Democratic Party                            0.001815
# ...

# %%
data2020["Party"].value_counts(normalize=True)
# Out:
# Non-Party                            0.244821
# Fianna Fáil                          0.158192
# Fine Gael                            0.154426
# Sinn Féin                            0.079096
# Green Party/ Comhaontas Glas         0.073446
# Solidarity - People Before Profit    0.069680
# The Labour Party                     0.058380
# Aontu                                0.047081
# Social Democrats                     0.037665
# Renua Ireland                        0.020716
# Irish Freedom Party                  0.018832
# The National Party                   0.018832
# Workers Party                        0.007533
# Independents 4 Change                0.007533
# United People                        0.001883
# Irish Democratic Party               0.001883
# Name: Party, dtype: float64

# %%
#sorting, indexing, grouping

# %%
#summaries by grouping

# %%
data2016.groupby("Gender")["Votes"].mean()
# Out:
# Gender
# F    3272.503067
# M    4122.363402
# Name: Votes, dtype: float64

# %%
data2020.groupby("Gender")["Votes"].mean()
# Out:
# Gender
# F    3612.583851
# M    4329.359459
# Name: Votes, dtype: float64

# %%
data2016.groupby(["Party","Result","Gender"])["Votes"].sum()
# Out:
# Party                                           Result    Gender
# Anti-Austerity Alliance - People Before Profit  Elected   F          10894
#                                                           M          31450
#                                                 Excluded  F          15887
#                                                           M          25937
# Catholic Democrats                              Excluded  F           1359
#                                                           M            654
# Communist Party of Ireland                      Excluded  M            185
# Direct Democracy Ireland                        Excluded  F            579
#                                                           M           5902
# Fianna Fáil                                     Elected   F          47418
#                                                           M         356368
#                                                 Excluded  F          46071
# ...

# %%
votes_bytype = data2016.groupby("Result")["Votes"].sum()
gendervotes_propn_by_type = votes_bytype / sum(votes_bytype)
print(gendervotes_propn_by_type)
# Out:
# Result
# Elected     0.602785
# Excluded    0.333917
# Unknown     0.063298
# Name: Votes, dtype: float64

# %%
votes_bytype = data2020.groupby("Result")["Votes"].sum()
gendervotes_propn_by_type = votes_bytype / sum(votes_bytype)
print(gendervotes_propn_by_type)
# Out:
# Result
# Elected     0.637635
# Excluded    0.296898
# Unknown     0.065467
# Name: Votes, dtype: float64

# %%
data2016.columns
# Out:
# Index(['Constituency', 'Surname', 'First Name', 'Gender', 'Party',
#        'Party Abbreviation', 'Count Number', 'Required To Reach Quota',
#        'Required To Save Deposit', 'Votes', 'Result', 'Candidate Id',
#        'Constituency Number', 'Constituency Ainm', 'Year', 'Full Name'],
#       dtype='object')

# %%
gender_result_stats=data2016.groupby("Result")[["Gender", "Votes"]].agg([np.min, np.max, np.mean, np.median])
print(gender_result_stats)
# Out:
#          Votes
#           amin   amax         mean  median
# Result
# Elected   1990  20378  8189.025478  7798.0
# Excluded    22   7260  1924.891892  1427.5
# Unknown   2633   8373  5625.333333  5830.0

# %%
data2016.pivot_table(values="Votes",index="Gender",aggfunc=[np.mean, np.median])
# Out:
#                mean median
#               Votes  Votes
# Gender
# F       3272.503067   2633
# M       4122.363402   3232

# %%
data2016.pivot_table(values="Votes",index="Gender",columns="Result",fill_value=0,margins=True)
# Out:
# Result      Elected     Excluded      Unknown          All
# Gender
# F       7081.200000  1984.575000  5928.375000  3272.503067
# M       8506.844262  1896.244000  5473.812500  4122.363402
# All     8189.025478  1924.891892  5625.333333  3870.952813

# %%
data2016[["Candidate Id","Full Name", "Gender", "Votes", "Result", "Party","Count Number",]]
# Out:
#      Candidate Id             Full Name Gender  Votes    Result  \
# 0             165          Éamon Ó Cuív      M   9539   Elected
# 1             160            GerryAdams      M  10661   Elected
# 2             169          BarbaraAhern      F   4594   Unknown
# 3             160  Sheik MohiuddinAhmed      M    140  Excluded
# 4             187       PatrickAkpoveta      M    288  Excluded
# ..            ...                   ...    ...    ...       ...
# 546           242      RaymondWhitehead      M    213  Excluded
# 547           174            JohnWilson      M   1023  Excluded
# 548           175             MaeveYore      F   2746  Excluded
# 549           173          BrendanYoung      M   1200  Excluded
# 550           222      KatherineZappone      F   4463   Elected
#
#                         Party  Count Number
# 0                 Fianna Fáil            14
# 1                   Sinn Féin            11
# 2                 Fianna Fáil            10
# ...

# %%
data2016.sort_values(by=['Votes'])
# Out:
#            Constituency    Surname     First Name Gender             Party  \
# 153         Galway West     Feeney        Patrick      M         Non-Party
# 194      Dublin Central     Gorman  William  D.j.      M         Non-Party
# 257    Dublin Bay South    Keigher   John Dominic      M         Non-Party
# 366               Clare   Mulqueen         Dermot      M         Non-Party
# 178                Mayo     Forkin           Sean      M         Non-Party
# ..                  ...        ...            ...    ...               ...
# 175               Laois    Fleming           Seán      M       Fianna Fáil
# 383    Roscommon-Galway   Naughten          Denis      M         Non-Party
# 258  Cork North-Central   Kelleher          Billy      M       Fianna Fáil
# 132             Wicklow   Donnelly        Stephen      M  Social Democrats
# 223               Kerry  Healy-Rae        Michael      M         Non-Party
#
#     Party Abbreviation  Count Number  Required To Reach Quota  \
# ...

# %%
#grouping
gendergrouping2016=data2016.groupby("Party").count()["Full Name"]

# %%
#Keeping the columns that I want to see - creating a sub dataframe
data2016[["Full Name", "Surname", "First Name", "Constituency","Gender","Party","Count Number","Votes","Result"]]
# Out:
#                 Full Name    Surname       First Name       Constituency  \
# 0            Éamon Ó Cuív     Ó Cuív            Éamon        Galway West
# 1              GerryAdams      Adams            Gerry              Louth
# 2            BarbaraAhern      Ahern          Barbara         Cork  East
# 3    Sheik MohiuddinAhmed      Ahmed  Sheik Mohiuddin          Waterford
# 4         PatrickAkpoveta   Akpoveta          Patrick    Dublin Mid-West
# ..                    ...        ...              ...                ...
# 546      RaymondWhitehead  Whitehead          Raymond      Dún Laoghaire
# 547            JohnWilson     Wilson             John     Cavan-Monaghan
# 548             MaeveYore       Yore            Maeve              Louth
# 549          BrendanYoung      Young          Brendan      Kildare North
# 550      KatherineZappone    Zappone        Katherine  Dublin South-West
#
#     Gender                     Party  Count Number  Votes    Result
# ...

# %%
# Checking to see how many candidates were elected

print("2020 Elected candidates:",data2020[(data2020['Result']=="Elected")].shape[0])
print("2016 Elected candidates",data2016[(data2016['Result']=="Elected")].shape[0])
# Out:
# 2020 Elected candidates: 159
# 2016 Elected candidates 157

# %% [markdown]
# # looping, iterrows

# %%
data2016.columns
# Out:
# Index(['Constituency', 'Surname', 'First Name', 'Gender', 'Party',
#        'Party Abbreviation', 'Count Number', 'Required To Reach Quota',
#        'Required To Save Deposit', 'Votes', 'Result', 'Candidate Id',
#        'Constituency Number', 'Constituency Ainm', 'Year', 'Full Name'],
#       dtype='object')

# %%
data2016.index
# Out:
# RangeIndex(start=0, stop=551, step=1)

# %%
Fullname_ind=data2016.set_index("Candidate Id")
print(Fullname_ind)
for index, rows in data2016.iterrows():
    print(index,': ','The Candidate', rows["Full Name"],  'was', rows["Result"], 'and their vote ', rows["Votes"], '.')
# Out:
#                    Constituency    Surname       First Name Gender  \
# Candidate Id
# 165                 Galway West     Ó Cuív            Éamon      M
# 160                       Louth      Adams            Gerry      M
# 169                  Cork  East      Ahern          Barbara      F
# 160                   Waterford      Ahmed  Sheik Mohiuddin      M
# 187             Dublin Mid-West   Akpoveta          Patrick      M
# ...                         ...        ...              ...    ...
# 242               Dún Laoghaire  Whitehead          Raymond      M
# 174              Cavan-Monaghan     Wilson             John      M
# 175                       Louth       Yore            Maeve      F
# 173               Kildare North      Young          Brendan      M
# 222           Dublin South-West    Zappone        Katherine      F
#
#                                  Party Party Abbreviation  Count Number  \
# Candidate Id
# ...

# %%
#merge Dataframes

# %%
#I'm going to bring in the 2020 count details which shows additional information such as spoiled votes, total electoral size
count2020=pd.read_csv("2020countdetails.csv")

# %%
data2020.head()
# Out:
#       Constituency   Surname First Name Gender          Party  \
# 0  Carlow-Kilkenny   AYLWARD      BOBBY      M    Fianna Fáil
# 1  Carlow-Kilkenny     BYRNE     HELENA      F  Renua Ireland
# 2  Carlow-Kilkenny   DEERING        PAT      M      Fine Gael
# 3  Carlow-Kilkenny  FUNCHION   KATHLEEN      F      Sinn Féin
# 4  Carlow-Kilkenny     HAYES       ALAN      M      Non-Party
#
#   Party Abbreviation  Count Number  Required To Reach Quota  \
# 0               F.F.            10                     2289
# 1               R.I.            10                        0
# 2               F.G.            10                        0
# 3               S.F.            10                        0
# 4             NON-P.            10                        0
#
#    Required To Save Deposit  Votes    Result  Candidate Id  \
# 0                         0   7550   Unknown           161
# 1                      1905    992  Excluded           162
# ...

# %%
#merging data sets - i'm going to bring in the count details

# %%
count2020=pd.read_csv("2020countdetails.csv", index_col=["Constituency Number"])
count2020.head()
# Out:
#                       Constituency Name           Constituency Ainm  \
# Constituency Number
# 1                       Carlow Kilkenny  Ceatharlach-Cill Chainnigh
# 2                        Cavan Monaghan        An Cabhán-Muineachán
# 3                                 Clare                     An Clár
# 4                             Cork East              Corcaigh Thoir
# 5                    Cork North Central        Corcaigh Thuaidh-Lár
#
#                      Count Number Date Of Election  Number Of Candidates  \
# Constituency Number
# 1                              10       08/02/2020                    14
# 2                              11       08/02/2020                    13
# 3                              10       08/02/2020                    15
# 4                               8       08/02/2020                    13
# 5                              14       08/02/2020                    18
#
#                      Number of Seats  Quota  Required Save Deposit  \
# ...

# %%
#merging candidate details with count details to get extra information such as total electorate, seats filled, total poll. Distinguishing repeated column names between 2 data sets with cand and count
candidate_count20 = data2020.merge(count2020,on="Constituency Number", suffixes=('_cand','count'))
candidate_count20.head()
# Out:
#       Constituency   Surname First Name Gender          Party  \
# 0  Carlow-Kilkenny   AYLWARD      BOBBY      M    Fianna Fáil
# 1  Carlow-Kilkenny     BYRNE     HELENA      F  Renua Ireland
# 2  Carlow-Kilkenny   DEERING        PAT      M      Fine Gael
# 3  Carlow-Kilkenny  FUNCHION   KATHLEEN      F      Sinn Féin
# 4  Carlow-Kilkenny     HAYES       ALAN      M      Non-Party
#
#   Party Abbreviation  Count Number_cand  Required To Reach Quota  \
# 0               F.F.                 10                     2289
# 1               R.I.                 10                        0
# 2               F.G.                 10                        0
# 3               S.F.                 10                        0
# 4             NON-P.                 10                        0
#
#    Required To Save Deposit  Votes  ... Number Of Candidates  Number of Seats  \
# 0                         0   7550  ...                   14                5
# ...

# %%
candidate_count20.describe()
# Out:
#        Count Number_cand  Required To Reach Quota  Required To Save Deposit  \
# count         531.000000               531.000000                 531.00000
# mean            9.444444               269.037665                 722.19209
# std             2.746906               709.048828                1014.01788
# min             5.000000                 0.000000                   0.00000
# 25%             8.000000                 0.000000                   0.00000
# 50%             9.000000                 0.000000                   0.00000
# 75%            11.000000                 0.000000                1579.00000
# max            15.000000              4462.000000                3223.00000
#
#               Votes  Candidate Id  Constituency Number  Unnamed: 14    Year  \
# count    531.000000    531.000000           531.000000          0.0   531.0
# mean    4112.032015    178.384181            58.504708          NaN  2020.0
# ...

# %%
candidate_count20.sort_values("Count Number_cand", ascending=False)
# Out:
#         Constituency   Surname First Name Gender  \
# 530          Wicklow  WHITMORE  JENNIEFER      F
# 517          Wicklow  DONNELLY    STEPHEN      M
# 515          Wicklow    CONNOR     SEAMUS      M
# 514          Wicklow     CASEY        PAT      M
# 513          Wicklow    BRIGGS     SHARON      F
# ..               ...       ...        ...    ...
# 76   Cork North West  McCARTHY   CIARï¿½N      M
# 75   Cork North West     KEALY      BECKY      F
# 74   Cork North West      FINN    COLETTE      F
# 73   Cork North West     CREED    MICHAEL      M
# 80   Cork North West   O'LEARY       SEAN      M
#
#                                  Party Party Abbreviation  Count Number_cand  \
# 530                   Social Democrats               S.D.                 15
# 517                        Fianna Fáil               F.F.                 15
# 515                              Aontu                 A.                 15
# ...

# %% [markdown]
# # 4.Python

# %%
#Define a custom function to create re-useable code

# %%
is_elected=candidate_count20["Result"]=="Elected"
candidate_count20[is_elected]
# Out:
#         Constituency             Surname First Name Gender  \
# 3    Carlow-Kilkenny            FUNCHION   KATHLEEN      F
# 6    Carlow-Kilkenny          McGUINNESS       JOHN      M
# 7    Carlow-Kilkenny  MURNANE Oï¿½CONNOR   JENNIFER      F
# 8    Carlow-Kilkenny              NOONAN    MALCOLM      M
# 11   Carlow-Kilkenny              PHELAN  JOHN PAUL      M
# ..               ...                 ...        ...    ...
# 512          Wicklow               BRADY       JOHN      M
# 517          Wicklow            DONNELLY    STEPHEN      M
# 522          Wicklow              HARRIS      SIMON      M
# 526          Wicklow            MATTHEWS     STEVEN      M
# 530          Wicklow            WHITMORE  JENNIEFER      F
#
#                             Party Party Abbreviation  Count Number_cand  \
# 3                       Sinn Féin               S.F.                 10
# 6                     Fianna Fáil               F.F.                 10
# ...

# %%
is_male = candidate_count20["Gender"]=="M"
is_elected=candidate_count20["Result"]=="Elected"
electedmales2020=candidate_count20[is_male & is_elected]
is_female = candidate_count20["Gender"]=="F"
is_elected=candidate_count20["Result"]=="Elected"
electedfemales2020=candidate_count20[is_female & is_elected]

# %%
sns.countplot(x="Party",data=is_elected)
plt.xticks(rotation=90)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\MEABHM~1\AppData\Local\Temp/ipykernel_14200/2167863719.py in <module>
# ----> 1 sns.countplot(x="Party",data=is_elected)
#       2 plt.xticks(rotation=90)
#       3 plt.show()
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3596         raise ValueError("Cannot pass values for both `x` and `y`")
#    3597
# -> 3598     plotter = _CountPlotter(
#    3599         x, y, hue, data, order, hue_order,
# ...

# %%
=candidate_count20["Result"]=="Elected".drop(rows={"Unknown"})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\MEABHM~1\AppData\Local\Temp/ipykernel_14200/2746882639.py in <module>
# ----> 1 is_elected=candidate_count20["Result"]=="Elected".drop(rows={"Unknown"})
#
# AttributeError: 'str' object has no attribute 'drop'

# %%
sns.countplot(x="Party",data=is_elected)
plt.xticks(rotation=90)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\MEABHM~1\AppData\Local\Temp/ipykernel_14200/2167863719.py in <module>
# ----> 1 sns.countplot(x="Party",data=is_elected)
#       2 plt.xticks(rotation=90)
#       3 plt.show()
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3596         raise ValueError("Cannot pass values for both `x` and `y`")
#    3597
# -> 3598     plotter = _CountPlotter(
#    3599         x, y, hue, data, order, hue_order,
# ...

# %% [markdown]
# # 5. Visualise

# %%
#matplotlib

# %%
#here i want to show the difference in the number of elected males vs females
candidate_count20[is_elected]["Gender"].hist(bins=3)
plt.show()

# %%
avg_votes_bygender=candidate_count20[is_elected].groupby("Gender")["Votes"].mean()
print(avg_votes_bygender)
# Out:
# Gender
# F    8748.250000
# M    8758.796748
# Name: Votes, dtype: float64

# %%
avg_votes_bygender.plot(kind="bar",title="Mean votes by Gender")
plt.show()

# %%
#What Female candidate had the most votes received and sort by how many counts it took to get elected. Subset of columns from database
candidate_count20[is_elected].sort_values(["Votes", "Count Number_cand"], ascending=[False,True])
candidate_count20[is_elected][["Constituency","Surname","First Name","Gender","Result","Party","Votes","Count Number_cand"]]
# Out:
#         Constituency             Surname First Name Gender   Result  \
# 3    Carlow-Kilkenny            FUNCHION   KATHLEEN      F  Elected
# 6    Carlow-Kilkenny          McGUINNESS       JOHN      M  Elected
# 7    Carlow-Kilkenny  MURNANE Oï¿½CONNOR   JENNIFER      F  Elected
# 8    Carlow-Kilkenny              NOONAN    MALCOLM      M  Elected
# 11   Carlow-Kilkenny              PHELAN  JOHN PAUL      M  Elected
# ..               ...                 ...        ...    ...      ...
# 512          Wicklow               BRADY       JOHN      M  Elected
# 517          Wicklow            DONNELLY    STEPHEN      M  Elected
# 522          Wicklow              HARRIS      SIMON      M  Elected
# 526          Wicklow            MATTHEWS     STEVEN      M  Elected
# 530          Wicklow            WHITMORE  JENNIEFER      F  Elected
#
#                             Party  Votes  Count Number_cand
# 3                       Sinn Féin  17493                 10
# ...

# %%
electedfemales2020=candidate_count20[is_female & is_elected]
electedfemales2020["Party"].value_counts(sort=True)
# Out:
# Sinn Féin                            13
# Fine Gael                             6
# Fianna Fáil                           5
# Social Democrats                      4
# Non-Party                             4
# Green Party/ Comhaontas Glas          2
# Independents 4 Change                 1
# Solidarity - People Before Profit     1
# Name: Party, dtype: int64

# %%
#Data Insights 2 - What constituency is more likely to return a female elected candidate?
electedfemales2020["Constituency"].value_counts(sort=True)
# Out:
# Galway West             3
# Cavan-Monaghan          3
# Dublin Rathdown         2
# Kildare North           2
# Dublin South Central    2
# Carlow-Kilkenny         2
# Dublin Central          2
# Dublin Fingal           1
# Laois-Offaly            1
# Wexford                 1
# Waterford               1
# Sligo-Leitrim           1
# Roscommon-Galway        1
# Meath East              1
# Mayo                    1
# Louth                   1
# Longford-Westmeath      1
# Kildare South           1
# Dublin Mid-West         1
# Clare                   1
# Kerry                   1
# Cork South West         1
# Galway East             1
# Dun Laoghaire           1
# Dublin Bay North        1
# Dublin North West       1
# Wicklow                 1
# Name: Constituency, dtype: int64

# %%
electedfemales2020.groupby(["Party","Constituency"])["Count Number_cand"].mean()
# Out:
# Party                              Constituency
# Fianna Fáil                        Carlow-Kilkenny         10.0
#                                    Cavan-Monaghan          11.0
#                                    Galway East              8.0
#                                    Kerry                    8.0
#                                    Waterford                7.0
# Fine Gael                          Cavan-Monaghan          11.0
#                                    Dublin Mid-West          9.0
#                                    Dublin Rathdown          8.0
#                                    Dun Laoghaire            8.0
#                                    Galway West             13.0
#                                    Meath East               7.0
# Green Party/ Comhaontas Glas       Dublin Central           9.0
#                                    Dublin Rathdown          8.0
# Independents 4 Change              Dublin South Central     6.0
# ...

# %%
electedfemales2020["Votes"].hist(bins=6)
plt.show()

# %%
is_elected["Count Number_cand"].hist(bins=6)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'Count Number_cand'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# C:\Users\MEABHM~1\AppData\Local\Temp/ipykernel_14200/3318111885.py in <module>
# ----> 1 is_elected["Count Number_cand"].hist(bins=6)
# ...

# %%
avg_votes_by_party = electedfemales2020.groupby("Party")["Votes"].mean()
print(avg_votes_by_party)
# Out:
# Party
# Fianna Fáil                           6871.600000
# Fine Gael                             7471.833333
# Green Party/ Comhaontas Glas          6404.500000
# Independents 4 Change                 2831.000000
# Non-Party                             5918.000000
# Sinn Féin                            12616.615385
# Social Democrats                      6916.750000
# Solidarity - People Before Profit     4753.000000
# Name: Votes, dtype: float64

# %%
avg_votes_by_party.plot(kind="bar",title="Mean Votes by Party")
plt.show()

# %%
candidate_count20[is_elected]
# Out:
#         Constituency             Surname First Name Gender  \
# 3    Carlow-Kilkenny            FUNCHION   KATHLEEN      F
# 6    Carlow-Kilkenny          McGUINNESS       JOHN      M
# 7    Carlow-Kilkenny  MURNANE Oï¿½CONNOR   JENNIFER      F
# 8    Carlow-Kilkenny              NOONAN    MALCOLM      M
# 11   Carlow-Kilkenny              PHELAN  JOHN PAUL      M
# ..               ...                 ...        ...    ...
# 512          Wicklow               BRADY       JOHN      M
# 517          Wicklow            DONNELLY    STEPHEN      M
# 522          Wicklow              HARRIS      SIMON      M
# 526          Wicklow            MATTHEWS     STEVEN      M
# 530          Wicklow            WHITMORE  JENNIEFER      F
#
#                             Party Party Abbreviation  Count Number_cand  \
# 3                       Sinn Féin               S.F.                 10
# 6                     Fianna Fáil               F.F.                 10
# ...

# %%
fig, ax =plt.subplots()
sns.distplot(candidate_count20["Votes"],ax=ax)
ax.set(xlabel="Votes")
# Out:
# C:\Users\Meabh Mc Donnell\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0.5, 0, 'Votes')]

# %%
candidate_count20[is_elected].plot(kind="bar",title="Mean Votes by Party")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # seaborn

# %%
sns.countplot(x="Gender", data=candidate_count20[is_elected])
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
sns.set(color_codes=True)
sns.distplot(candidate_count20["Votes"],color="g")
# Out:
# C:\Users\Meabh Mc Donnell\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Votes', ylabel='Density'>

# %%
sns.countplot(x="Gender",data=candidate_count20, hue="Result")
plt.show()

# %%
#Subgroups with point size!
sns.relplot(x="Count Number_cand",y = "Votes", data=candidate_count20[is_elected], kind = "scatter", size = "Gender", hue = "Gender")

# %%
#Subgroups with point size!
sns.relplot(x="Party",y = "Votes", data=candidate_count20[is_elected], kind = "scatter", size = "Gender", hue = "Gender")

# %%
#adding titles and lables

# %%
g=sns.catplot(x="Party", y="Votes",data=candidate_count20,kind="box")
plt.xticks(rotation=90)
g.fig.suptitle("Votes by party", y="1.03")
sns.set_context("notebook")
plt.show()

# %%
for p in sns.palettes.SEABORN_PALETTES:
    sns.set_palette(p)
    sns.palplot(sns.color_palette())
    plt.show()

# %%
sns.set(color_codes=True)
sns.distplot(candidate_count20[is_elected]['Votes'], color='m')
# Out:
# C:\Users\Meabh Mc Donnell\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Votes', ylabel='Density'>

# %%
sns.stripplot(data=candidate_count20,y="Result",x="Votes",jitter=True)
# Out:
# <AxesSubplot:xlabel='Votes', ylabel='Result'>

# %%
sns.barplot(data=candidate_count20,y="Result",x="Votes",hue="Gender")
# Out:
# <AxesSubplot:xlabel='Votes', ylabel='Result'>

# %%
sns.countplot(data=candidate_count20[is_elected], y="Result",hue="Gender")
# Out:
# <AxesSubplot:xlabel='count', ylabel='Result'>

# %%
#plotting with regplot
sns.regplot(data=candidate_count20[is_elected],x="Count Number_cand",y="Total Electorate", marker="+")
# Out:
# <AxesSubplot:xlabel='Count Number_cand', ylabel='Total Electorate'>

# %%
sns.regplot(data=candidate_count20[is_elected],x="Count Number_cand",y="Votes",x_estimator=np.mean,order=2)
# Out:
# <AxesSubplot:xlabel='Count Number_cand', ylabel='Votes'>

# %%
sns.heatmap(pd.crosstab(candidate_count20[is_elected]["Constituency"],candidate_count20[is_elected]["Party"],values=candidate_count20[is_elected]["Total Electorate"],aggfunc="mean"))
# Out:
# <AxesSubplot:xlabel='Party', ylabel='Constituency'>

# %%
#Coming back to matplotlib!
fig, ax = plt.subplots()
ax.bar("F", candidate_count20[is_elected]["Votes"].mean())
ax.bar("M", candidate_count20[is_elected]["Votes"].mean())
ax.set_ylabel("Votes")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
